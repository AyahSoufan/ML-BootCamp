# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from scipy import stats
from scipy.stats import norm, skew #for some statistics
import statsmodels.api as sm
import statsmodels
from statsmodels.regression import linear_model

# %%
#Load Data
train= pd.read_csv(r"C:\Users\Ayah\Desktop\bootcamp\Data\Credit.csv")
train.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
#train.Balance

# %%
Y = train['Balance']
X = train
del X['Balance']
train_dummy = pd.get_dummies(X)
train_num= train_dummy.select_dtypes([np.number])
train_num = sm.add_constant(train_num)

# %%
model = sm.OLS(Y, train_num, missing='drop')
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     687.7
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):          2.00e-252
# Time:                        09:44:24   Log-Likelihood:                -2398.2
# No. Observations:                 400   AIC:                             4822.
# Df Residuals:                     387   BIC:                             4874.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
results_Ridge = model.fit_regularized(L1_wt=0, alpha=5, start_params=result.params)
ridge = sm.regression.linear_model.OLSResults(model, 
                                              results_Ridge.params, 
                                              model.normalized_cov_params)
ridge.summary()
#if you make alpha big more coffecient goes zero
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     202.4
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):          1.98e-158
# Time:                        10:06:06   Log-Likelihood:                -2622.4
# No. Observations:                 400   AIC:                             5271.
# Df Residuals:                     387   BIC:                             5323.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     322.6
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):          4.52e-193
# Time:                        09:46:36   Log-Likelihood:                -2539.7
# No. Observations:                 400   AIC:                             5105.
# Df Residuals:                     387   BIC:                             5157.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
results_LASSO = model.fit_regularized(L1_wt=1, alpha=4, start_params=result.params)
LASSO = sm.regression.linear_model.OLSResults(model, 
                                              results_LASSO.params, 
                                              model.normalized_cov_params)
LASSO.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     642.8
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):          5.04e-247
# Time:                        10:06:55   Log-Likelihood:                -2411.1
# No. Observations:                 400   AIC:                             4848.
# Df Residuals:                     387   BIC:                             4900.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...
